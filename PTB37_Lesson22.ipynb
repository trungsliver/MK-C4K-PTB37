# %%
import pandas as pd
import numpy as np

# %%
from google.colab import files
files.upload()    # spotify.csv
# Out:
#      <input type="file" id="files-24c9c5d5-591e-401e-9f2d-c6201c7440f8" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-24c9c5d5-591e-401e-9f2d-c6201c7440f8">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
# Đọc dữ liệu
df = pd.read_csv('spotify.csv')
df
# Out:
#            Date  Shape of You  Despacito  Something Just Like This    HUMBLE.  \
# 0    2017-01-06      12287078        NaN                       NaN        NaN
# 1    2017-01-07      13190270        NaN                       NaN        NaN
# 2    2017-01-08      13099919        NaN                       NaN        NaN
# 3    2017-01-09      14506351        NaN                       NaN        NaN
# 4    2017-01-10      14275628        NaN                       NaN        NaN
# ..          ...           ...        ...                       ...        ...
# 361  2018-01-05       4492978  3450315.0                 2408365.0  2685857.0
# 362  2018-01-06       4416476  3394284.0                 2188035.0  2559044.0
# 363  2018-01-07       4009104  3020789.0                 1908129.0  2350985.0
# 364  2018-01-08       4135505  2755266.0                 2023251.0  2523265.0
# 365  2018-01-09       4168506  2791601.0                 2058016.0  2727678.0
#
#      Unforgettable
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 366 entries, 0 to 365
# Data columns (total 6 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Date                      366 non-null    object
#  1   Shape of You              366 non-null    int64
#  2   Despacito                 359 non-null    float64
#  3   Something Just Like This  319 non-null    float64
#  4   HUMBLE.                   282 non-null    float64
#  5   Unforgettable             275 non-null    float64
# dtypes: float64(4), int64(1), object(1)
# memory usage: 17.3+ KB

# %%
# convert kiểu dữ liệu cột 'Date'
df['Date'] = pd.to_datetime(df['Date'], format='%Y-%m-%d')
df.dtypes
# Out:
# Date                        datetime64[ns]
# Shape of You                         int64
# Despacito                          float64
# Something Just Like This           float64
# HUMBLE.                            float64
# Unforgettable                      float64
# dtype: object

# %% [markdown]
# ## **Thư viện Matplotlib**

# %% [markdown]
# - Khái niệm: thư viện phổ biến để tạo các loại biểu đồ
# - 1 số thuộc thính hay dùng: <br>
#       + figure(figsize=(h,w)): tạo biểu đồ với kích thước tùy chỉnh, đơn vị inch
#       <br>
#       + legend: nhãn/label của các cột
#       <br>
#       + xlabel, ylabel: nhãn của trục x và trục y
#       <br>
#       + title: tên biểu đồ
#       <br>
# - Sau khi chỉnh sửa, dùng plt.show() để hiển thị biểu đồ

# %%
# Thêm thư viện để chỉnh sửa thuộc tính của biểu đồ
import matplotlib.pyplot as plt

# %% [markdown]
# ## **Biểu đồ đường - Line Chart**
# - Kết nối dữ liệu riêng lẻ
# - Thể hiện xu hướng (trend) của 1 chuỗi dữ liệu

# %%
df.plot.line(x='Date')
# Out:
# <Axes: xlabel='Date'>

# %%
# figure(figsize=(h,w)): tạo biểu đồ và thay đổi kích thước (đơn vị inch)
plt.figure(figsize=(14,6))
df_line = df.set_index('Date')
plt.plot(df_line)

# legend: hiển thị nhãn của các cột
# xlabel, ylabel hiển thị nhãn của các cột
plt.legend(df_line.columns)
plt.ylabel('Views')

# title: hiển thị tên biểu đồ
plt.title('Spotify song views from January 2017 to January 2018')

# HIển thị biểu đồ
plt.show()

# %% [markdown]
# ## **Biểu đồ cột - Bar Chart**
# - Biểu diễn thông tin riêng lẻ rõ ràng
# - Tập trung vào các giá trị riêng lẻ

# %%
files.upload()    # Billionaires.csv
# Out:
#      <input type="file" id="files-116b3824-03a7-4b1a-a542-221f28302d1e" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-116b3824-03a7-4b1a-a542-221f28302d1e">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
df = pd.read_csv('Billionaires.csv')
df
# Out:
#       Rank                      Name Net Worth   Age Country | Territory  \
# 0        1  Bernard Arnault & family    $211 B  74.0              France
# 1        2                 Elon Musk    $180 B  51.0       United States
# 2        3                Jeff Bezos    $114 B  59.0       United States
# 3        4             Larry Ellison    $107 B  78.0       United States
# 4        5            Warren Buffett    $106 B  92.0       United States
# ...    ...                       ...       ...   ...                 ...
# 2635  2540                   Yu Rong      $1 B  51.0               China
# 2636  2540    Richard Yuengling, Jr.      $1 B  80.0       United States
# 2637  2540             Zhang Gongyun      $1 B  60.0               China
# 2638  2540    Zhang Guiping & family      $1 B  71.0               China
# 2639  2540               Inigo Zobel      $1 B  66.0         Philippines
#
#                             Source               Industry
# ...

# %%
# Làm sạch dữ liệu & chuyển đổi kiểu dữ liệu của cột 'Net worth'
def clean_networth(networth):
    return networth[1:-1]

# df["Net Worth"] = df["Net Worth"].apply(lambda x: x[1:-1])
df["Net Worth"] = df["Net Worth"].apply(clean_networth)
df["Net Worth"] = pd.to_numeric(df["Net Worth"])
df.head()
# Out:
#    Rank                      Name  Net Worth   Age Country | Territory  \
# 0     1  Bernard Arnault & family      211.0  74.0              France
# 1     2                 Elon Musk      180.0  51.0       United States
# 2     3                Jeff Bezos      114.0  59.0       United States
# 3     4             Larry Ellison      107.0  78.0       United States
# 4     5            Warren Buffett      106.0  92.0       United States
#
#                Source               Industry
# 0                LVMH       Fashion & Retail
# 1       Tesla, SpaceX             Automotive
# 2              Amazon             Technology
# 3              Oracle             Technology
# 4  Berkshire Hathaway  Finance & Investments

# %%
# Tính tổng Net Worth theo Industry và sắp xếp
df_industry= df[["Industry", "Net Worth"]].groupby("Industry").sum()
df_industry = df_industry.sort_values(by='Net Worth', ascending=False)
df_industry
# Out:
#                             Net Worth
# Industry
# Technology                     1871.0
# Fashion & Retail               1698.8
# Finance & Investments          1605.1
# Manufacturing                  1025.9
# Food & Beverage                 957.2
# Diversified                     905.2
# Real Estate                     657.4
# Healthcare                      643.2
# Automotive                      525.3
# Energy                          453.5
# Metals & Mining                 446.8
# Media & Entertainment           427.5
# Logistics                       239.5
# Telecom                         203.5
# Service                         173.4
# Sports                          134.5
# Gambling & Casinos              120.5
# Construction & Engineering      118.5

# %% [markdown]
# **Biểu đồ cột biểu diễn top 10 lĩnh vực có tổng tài sản cao nhất**
# - Mỗi cột đại diện cho 1 lĩnh vực
# - Tổng tài sản của lĩnh vực được biểu diễn bằng độ cao của cột

# %%
# Tạo DataFrame gồm top 10 lĩnh vực có tổng tài sản lớn nhất
df_topindustry = df_industry[:10]

# %%
# Vẽ biểu đồ cột
plt.bar(x=df_topindustry.index, height=df_topindustry['Net Worth'])
# Xoay label ở trục x 90 độ
plt.xticks(rotation=90)

plt.ylabel('Net Worth ($B)')
plt.title('Top 10 Net Worth by Industry')
plt.show()

# %% [markdown]
# **Top 5 người giàu nhất thế giới**

# %%
# Vẽ biểu đồ cột
plt.bar(x=df['Name'][:5], height=df['Net Worth'][:5])
# Xoay label ở trục x 90 độ
plt.xticks(rotation=90)

plt.ylabel('Net Worth ($B)')
plt.title('Top 5 Richest Billionares')
plt.show()

# %% [markdown]
# ## **Biểu đồ tần suất - Histogram**
# - Sử dụng nhiều cột (bar) để biểu diễn phân phối của dữ liệu
# - Chiều cao của cột thể hiện số lần xuất hiện của giá trị cột đó

# %%
# Biểu đồ tần suất biểu diễn phân phối tuổi của các tỉ phú
plt.hist(
    x=df["Age"],
    edgecolor='white'
    )
plt.title("Forbes's 2024 Billionaires Age Distribution")
plt.ylabel("Count")
plt.xlabel("Age")
plt.show()

# %% [markdown]
# ## **Biểu đồ phân tán - Scatter Plot**
# - Là dạng biểu đồ phân phối
# - Sử dụng các điểm dữ liệu (point) để biểu diễn mối quan hệ mạnh - yếu giữa các biến

# %% [markdown]
# Khi xem xem xét biểu đồ phân tán, cần xét:
# - Các điểm dữ liệu tụ lại hay tán ra
# - Phân phối dương hay âm (sang trái hay sang phải)

# %% [markdown]
# **Biểu đồ phân tán biểu diễn mỗi quan hệ giữa tuổi và tổng tài sản**
# - Mỗi điểm dữ liệu sẽ thể hiện cả 2 giá trị: tuổi, tổng tài sản
# - Tập hợp các điểm dữ liệu biểu diễn được phân phối giữa tuổi tác và tổng tài sản

# %%
plt.scatter(
    x=df["Age"],
    y=df["Net Worth"],
    s=30,
    linewidths=0.1,
    edgecolors='black'
)
plt.title("2024 Billionaires's Age w.r.t Net Worth")
plt.xlabel("Age")
plt.ylabel("Net Worth ($B)")
plt.show()

# %% [markdown]
# ## **Biểu đồ hộp - Box Plot**
# - Tác dụng: so sánh dữ liệu với giá trị trung bình

# %%
pip install pycountry-convert
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.0/8.0 MB 71.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 257.1/257.1 kB 8.4 MB/s eta 0:00:00
# ...

# %%
import pycountry_convert as pc

# %%
# Lấy tên châu lục thông qua tên quốc gia
def get_continent(country_name):
    try:
        country_code = pc.country_name_to_country_alpha2(country_name)
        continent_code = pc.country_alpha2_to_continent_code(country_code)
        continent_name = pc.convert_continent_code_to_continent_name(continent_code)
        return continent_name

    except:
        print(country_name)
        return "Unknown"

df["Country | Territory"] = df["Country | Territory"].replace({"Eswatini (Swaziland)":"Swaziland"})
df["Continent"] = df["Country | Territory"].apply(get_continent)

# %% [markdown]
# **Biểu đồ hộp biểu diễn phân phối top tài sản (>50 tỷ) theo châu lục**
# - Mỗi hộp thể hiện phân phối của 1 châu lục
# - Đường màu cam ở giữa thể hiện giá trị trung bình (median)

# %%
grouped = df[df["Net Worth"]>50].groupby('Continent')['Net Worth'].apply(list)
plt.boxplot(grouped, tick_labels=grouped.index)
plt.xlabel('Continent')
plt.ylabel('Net Worth')
plt.title("Distribution of top richest billionaires (Net Worth >$50B ) grouped by continent")
plt.show()

# %% [markdown]
# ## **Biểu đồ tròn - Pie Chart**

# %%
import matplotlib.cm as cm

df_continent_networth = df.groupby('Continent')['Net Worth'].sum().sort_values(ascending=False)

# Tạo một ánh xạ (mapping) tên châu lục từ tiếng Anh sang tiếng Việt
continent_name_map = {
    'North America': 'Bắc Mỹ',
    'Asia': 'Châu Á',
    'Europe': 'Châu Âu',
    'South America': 'Nam Mỹ',
    'Oceania': 'Châu Đại Dương',
    'Africa': 'Châu Phi'
}

plt.figure(figsize=(10, 8)) # Tăng kích thước biểu đồ để chứa chú thích (legend)

# Lấy bảng màu cho các màu sắc khác nhau
colors = cm.tab20(np.arange(len(df_continent_networth)))

# Tạo biểu đồ tròn
wedges, texts, autotexts = plt.pie(
    df_continent_networth,
    autopct='%1.1f%%', # Định dạng phần trăm với một chữ số thập phân
    startangle=90,
    wedgeprops={'edgecolor': 'black'},
    colors=colors, # Áp dụng màu từ bảng màu
    pctdistance=0.85 # Định vị nhãn phần trăm hơi ra xa tâm một chút
)

# Điều chỉnh cỡ chữ cho các nhãn phần trăm (autotexts)
for autotext in autotexts:
    autotext.set_fontsize(9) # Đặt cỡ chữ nhỏ hơn cho phần trăm

# Thêm chú thích (legend) bên ngoài biểu đồ tròn
plt.legend(
    wedges, # Sử dụng các miếng bánh làm đối tượng cho chú thích
    [continent_name_map.get(name, name) for name in df_continent_networth.index], # Dịch tên châu lục
    title="Châu lục",
    loc="center left", # Định vị chú thích ở giữa bên trái
    bbox_to_anchor=(1, 0, 0.5, 1) # Neo chú thích bên ngoài, phía bên phải của biểu đồ
)

plt.title('Tổng giá trị tài sản ròng theo châu lục')
plt.axis('equal') # Đảm bảo biểu đồ tròn được vẽ dưới dạng hình tròn
plt.tight_layout() # Điều chỉnh bố cục để tránh nhãn bị cắt
plt.show()

# %%
# Đếm số lượng tỷ phú trong mỗi lĩnh vực và lấy top 5
df_industry_count = df['Industry'].value_counts().head(5)

plt.figure(figsize=(8, 8)) # Tạo một khung vẽ với kích thước 8x8 inch

# Vẽ biểu đồ tròn
plt.pie(
    df_industry_count, # Dữ liệu để tạo biểu đồ
    labels=df_industry_count.index, # Nhãn cho các lát cắt (tên lĩnh vực)
    autopct='%1.1f%%', # Định dạng hiển thị phần trăm trên biểu đồ (một chữ số thập phân)
    startangle=90, # Góc bắt đầu của lát cắt đầu tiên (quay 90 độ)
    wedgeprops={'edgecolor': 'black'} # Định dạng đường viền của các lát cắt
)

plt.title('Top 5 Lĩnh vực có nhiều tỷ phú nhất') # Đặt tiêu đề cho biểu đồ
plt.axis('equal') # Đảm bảo biểu đồ tròn được vẽ đúng hình tròn
plt.show() # Hiển thị biểu đồ
